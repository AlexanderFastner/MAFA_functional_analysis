# MAFAWT_016  CTRL_WT_T2
# MAFAWT_017  CTRL_WT_T2
# MAFAWT_018  CTRL_WT_T1
# MAFAWT_019  CTRL_WT_T1
# MAFAWT_020  CTRL_WT_T1

# %%
adata.obs['condition'] = metadata['Treatment']
adata.obs['time_point'] = metadata['TimePoint']
adata.obs['DOX'] = metadata['DOX']
adata.obs
# Out:
#            condition time_point DOX
# MAFAWT_001      MAFA         T0   N
# MAFAWT_002      MAFA         T0   N
# MAFAWT_003      MAFA         T0   N
# MAFAWT_004      MAFA         T0   N
# MAFAWT_005      MAFA         T2   Y
# MAFAWT_006      MAFA         T2   Y
# MAFAWT_007      MAFA         T2   Y
# MAFAWT_008      MAFA         T2   Y
# MAFAWT_009      MAFA         T1   Y
# MAFAWT_010      MAFA         T1   Y
# MAFAWT_011      MAFA         T1   Y
# MAFAWT_012   Control         T0   N
# MAFAWT_013   Control         T0   N
# MAFAWT_014   Control         T0   N
# MAFAWT_015   Control         T2   Y
# MAFAWT_016   Control         T2   Y
# MAFAWT_017   Control         T2   Y
# MAFAWT_018   Control         T1   Y
# MAFAWT_019   Control         T1   Y
# MAFAWT_020   Control         T1   Y

# %%
# split data set by timepoint
#subset_t0 = adata[adata.obs.time_point == 'T0']
subset_t1 = adata[adata.obs.time_point == 'T1']
#subset_t2 = adata[adata.obs.time_point == 'T2']
# print("Subset for time point T0:")
# print(subset_t0)
# subset_t0.obs
print("\nSubset for time point T1:")
print(subset_t1)
subset_t1.obs
# print("\nSubset for time point T2:")
# print(subset_t2)
# Out:
# Subset for time point T1:
# View of AnnData object with n_obs × n_vars = 6 × 58735
#     obs: 'condition', 'time_point', 'DOX'
#            condition time_point DOX
# MAFAWT_009      MAFA         T1   Y
# MAFAWT_010      MAFA         T1   Y
# MAFAWT_011      MAFA         T1   Y
# MAFAWT_018   Control         T1   Y
# MAFAWT_019   Control         T1   Y
# MAFAWT_020   Control         T1   Y

# %% [markdown]
# ## Quality Control

# %%
#check various filter points
#old
dc.plot_filter_by_expr(adata, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1)
dc.plot_filter_by_expr(subset_t1, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1,save='../figures/WT/t1_QC.png')

# %%
# Obtain genes that pass the thresholds
genes = dc.filter_by_expr(subset_t1, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1)
genes.size
# Out:
# 15387

# %%
# Filter by these genes
adata = subset_t1[:, genes].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 6 × 15387
#     obs: 'condition', 'time_point', 'DOX'

# %%
#!pip install pydeseq2

# %%
# Import DESeq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
adata.X = np.round(adata.X,0)

# %%
# Build DESeq2 object
dds = DeseqDataSet(
    adata=adata,
    design_factors='condition',
    refit_cooks=True,
    n_cpus=8,
)

# %%
# Compute LFCs
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.01 seconds.
# Fitting dispersions...
# ... done in 33.26 seconds.
#
# Fitting dispersion trend curve...
# ... done in 8.92 seconds.
#
# Fitting MAP dispersions...
# ... done in 42.81 seconds.
#
# Fitting LFCs...
# ... done in 2.77 seconds.
#
# Refitting 0 outliers.

# %%
# Extract contrast 
stat_res = DeseqStats(dds, contrast=["condition", 'MAFA', 'Control'], n_cpus=8)

# %%
# Compute Wald test
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition MAFA vs Control
# ... done in 1.65 seconds.
#                  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_name
# CHGA        769588.437500       -0.111524  0.114925 -0.970412  0.331841
# MT-CO1      229631.187500       -0.191076  0.222381 -0.859229  0.390214
# GCG         263835.031250       -0.085354  0.243285 -0.350839  0.725709
# INS         119417.250000       -0.074432  0.267863 -0.277872  0.781110
# MT-ND4       94348.117188       -0.279559  0.261160 -1.070451  0.284417
# ...                   ...             ...       ...       ...       ...
# AC243830.2      14.226007        0.068780  0.499289  0.137756  0.890434
# AL355472.1      13.722759        0.055741  0.496541  0.112259  0.910618
# AL445253.1      14.631626        0.174465  0.481902  0.362033  0.717327
# MIR325HG        14.858451        0.264775  0.480193  0.551393  0.581364
# LRRC8C-DT       13.722785        0.104275  0.316736  0.329219  0.741990
#
#                 padj
# gene_name
# CHGA        0.488196
# MT-CO1      0.549134
# GCG         0.825557
# INS         0.864051
# MT-ND4      0.437107
# ...              ...
# AC243830.2  0.935165
# AL355472.1  0.947650
# AL445253.1  0.819719
# MIR325HG    0.716095
# LRRC8C-DT   0.836649
#
# [15387 rows x 6 columns]

# %%
# Shrink LFCs
stat_res.lfc_shrink(coeff='condition_MAFA_vs_Control')
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition MAFA vs Control
# ... done in 5.44 seconds.
#                  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_name
# CHGA        769588.437500        2.201599  0.146284 -0.970412  0.331841
# MT-CO1      229631.187500       -0.018945  0.206045 -0.859229  0.390214
# GCG         263835.031250        2.525468  0.312111 -0.350839  0.725709
# INS         119417.250000       -0.039913  0.231424 -0.277872  0.781110
# MT-ND4       94348.117188       -0.169738  0.244619 -1.070451  0.284417
# ...                   ...             ...       ...       ...       ...
# AC243830.2      14.226007        0.020279  0.334902  0.137756  0.890434
# AL355472.1      13.722759        0.016598  0.333277  0.112259  0.910618
# AL445253.1      14.631626        0.054108  0.334152  0.362033  0.717327
# MIR325HG        14.858451        0.083405  0.340197  0.551393  0.581364
# LRRC8C-DT       13.722785       -0.144270  0.459421  0.329219  0.741990
#
#                 padj
# gene_name
# CHGA        0.488196
# MT-CO1      0.549134
# GCG         0.825557
# INS         0.864051
# MT-ND4      0.437107
# ...              ...
# AC243830.2  0.935165
# AL355472.1  0.947650
# AL445253.1  0.819719
# MIR325HG    0.716095
# LRRC8C-DT   0.836649
#
# [15387 rows x 6 columns]

# %%
# Extract results
results_df = stat_res.results_df
results_df
# Out:
#                  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_name
# CHGA        769588.437500        2.201599  0.146284 -0.970412  0.331841
# MT-CO1      229631.187500       -0.018945  0.206045 -0.859229  0.390214
# GCG         263835.031250        2.525468  0.312111 -0.350839  0.725709
# INS         119417.250000       -0.039913  0.231424 -0.277872  0.781110
# MT-ND4       94348.117188       -0.169738  0.244619 -1.070451  0.284417
# ...                   ...             ...       ...       ...       ...
# AC243830.2      14.226007        0.020279  0.334902  0.137756  0.890434
# AL355472.1      13.722759        0.016598  0.333277  0.112259  0.910618
# AL445253.1      14.631626        0.054108  0.334152  0.362033  0.717327
# MIR325HG        14.858451        0.083405  0.340197  0.551393  0.581364
# LRRC8C-DT       13.722785       -0.144270  0.459421  0.329219  0.741990
#
#                 padj
# gene_name
# CHGA        0.488196
# MT-CO1      0.549134
# GCG         0.825557
# INS         0.864051
# MT-ND4      0.437107
# ...              ...
# AC243830.2  0.935165
# AL355472.1  0.947650
# AL445253.1  0.819719
# MIR325HG    0.716095
# LRRC8C-DT   0.836649
#
# [15387 rows x 6 columns]

# %%
#!pip install adjustText

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
dc.plot_volcano_df(
    results_df,
    x='log2FoldChange',
    y='padj',
    top=20,
    ax=ax
)
ax.set_xlim(-10, 10)
ax.set_ylim(0, 300)
plt.savefig('../figures/WT/t1_volcano.png')
# Out:
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
mat = results_df[['stat']].T.rename(index={'stat': 'treatment.vs.control'})
mat
# Out:
# gene_name                 CHGA    MT-CO1       GCG       INS    MT-ND4  \
# treatment.vs.control -0.970412 -0.859229 -0.350839 -0.277872 -1.070451
#
# gene_name               EEF1A1    MT-ND5       TTR   MT-CO2    MT-CYB  ...  \
# treatment.vs.control  2.540743 -0.702266 -4.449327 -2.10134 -1.328604  ...
#
# gene_name             AC116407.1    FAM27C     MTFR2    THSD7B  AC104561.1  \
# treatment.vs.control    0.044867 -0.147447 -1.132767 -0.200458    0.485176
#
# gene_name             AC243830.2  AL355472.1  AL445253.1  MIR325HG  LRRC8C-DT
# treatment.vs.control    0.137756    0.112259    0.362033  0.551393   0.329219
#
# [1 rows x 15387 columns]

# %% [markdown]
# ### Transcription factor activity inference

# %%
#collectri = dc.get_collectri(organism='human')
collectri = pd.read_csv("collectri.csv")
collectri
# Out:
#        source          target  weight  \
# 0         MYC            TERT       1
# 1        SPI1           BGLAP       1
# 2       SMAD3             JUN       1
# 3       SMAD4             JUN       1
# 4      STAT5A             IL2       1
# ...       ...             ...     ...
# 43173    NFKB  hsa-miR-143-3p       1
# 43174     AP1     hsa-miR-206       1
# 43175    NFKB   hsa-miR-21-5p       1
# 43176    NFKB  hsa-miR-224-5p       1
# 43177     AP1     hsa-miR-144       1
#
#                                                     PMID
# 0      10022128;10491298;10606235;10637317;10723141;1...
# 1                                               10022617
# 2                                      10022869;12374795
# 3                                      10022869;12374795
# 4      10022878;11435608;17182565;17911616;22854263;2...
# ...                                                  ...
# 43173                                           19472311
# 43174                                           19721712
# 43175                                  20813833;22387281
# 43176                                  23474441;23988648
# 43177                                           23546882
#
# [43178 rows x 4 columns]

# %% [markdown]
# ### Activity inference with Univariate Linear Model (ULM)

# %%
# Infer TF activities with ulm
tf_acts, tf_pvals = dc.run_ulm(mat=mat, net=collectri, verbose=True)
tf_acts
# Out:
# Running ulm on mat with 1 samples and 15387 targets for 645 sources.
#                           ABL1      AHR      AHRR      AIRE       AP1  \
# treatment.vs.control -1.869258 -1.94359 -0.845781 -1.759863 -0.316204
#
#                          APEX1        AR    ARID1A    ARID3A    ARID3B  ...  \
# treatment.vs.control -1.060564 -0.486711  0.966363 -2.165706 -0.441638  ...
#
#                        ZNF354C    ZNF362    ZNF382    ZNF384    ZNF395  \
# treatment.vs.control -1.779535  0.028057  0.531826 -3.519902 -0.492166
#
#                         ZNF436    ZNF699   ZNF76   ZNF804A     ZNF91
# treatment.vs.control -0.016086 -1.081644  0.6063 -2.050675 -1.273717
#
# [1 rows x 645 columns]

# %%
dc.plot_barplot(
    tf_acts,
    'treatment.vs.control',
    top=25,
    vertical=True,
    vmin=4,
    vmax=4,
    save='../figures/WT/t1_tf_activities.png'
)

# %% [markdown]
# # TF Activity with MLM

# %%
tf_acts_MLM, tf_pvals_MLM, = dc.run_mlm(mat=mat, net=collectri, verbose=True)
tf_acts_MLM
# Out:
# Running mlm on mat with 1 samples and 15387 targets for 645 sources.
#                           ABL1       AHR     AHRR     AIRE       AP1  \
# treatment.vs.control -1.050967 -1.184829  0.00058 -1.72124  2.144145
#
#                          APEX1        AR    ARID1A    ARID3A    ARID3B  ...  \
# treatment.vs.control -0.615754  0.277058  1.981325 -0.894439  0.617952  ...
#
#                        ZNF354C    ZNF362   ZNF382    ZNF384    ZNF395  \
# treatment.vs.control -1.348557  1.396282  0.05912 -2.750103 -0.894935
#
#                        ZNF436    ZNF699     ZNF76   ZNF804A     ZNF91
# treatment.vs.control  1.01664  1.124296  0.724142 -2.587812 -1.190721
#
# [1 rows x 645 columns]

# %%
dc.plot_barplot(
    tf_acts_MLM,
    'treatment.vs.control',
    top=25,
    vertical=True,
    vmin=4,
    vmax=4,
    save='../figures/WT/t1_tf_activities_MLM.png'
)

# %% [markdown]
# # Compare ULM and MLM results correlations

# %%
pearson_r, pearson_p = pearsonr(tf_acts.values.flatten(), tf_acts_MLM.values.flatten())
spearman_r, spearman_p = spearmanr(tf_acts.values.flatten(), tf_acts_MLM.values.flatten())

print(f"Pearson correlation: {pearson_r:.2f} (p-value: {pearson_p:.2e})")
print(f"Spearman correlation: {spearman_r:.2f} (p-value: {spearman_p:.2e})")
# Out:
# Pearson correlation: 0.66 (p-value: 2.23e-82)
# Spearman correlation: 0.63 (p-value: 1.45e-73)

# %% [markdown]
# # Find overlap in (Top 25)

# %%
ulm_top_25 = tf_acts.T.sort_values(by='treatment.vs.control', ascending=False).head(25).index
mlm_top_25 = tf_acts_MLM.T.sort_values(by='treatment.vs.control', ascending=False).head(25).index
len(set(ulm_top_25)&set(mlm_top_25)) / float(len(set(ulm_top_25) | set(mlm_top_25))) * 100
# Out:
# 13.636363636363635

# %% [markdown]
# # Find overlap in top 10% (Top 65)

# %%
ulm_top = tf_acts.T.sort_values(by='treatment.vs.control', ascending=False).head(int(len(tf_acts.T) * 0.1)).index
mlm_top = tf_acts_MLM.T.sort_values(by='treatment.vs.control', ascending=False).head(int(len(tf_acts_MLM.T) * 0.1)).index
#len(set(ulm_top)&set(mlm_top)) #length of overlap of both
#float(len(set(ulm_top))) #lengh of first list
# set(mlm_top))) * 100 scale to %
len(set(ulm_top)&set(mlm_top)) / float(len(set(ulm_top) | set(mlm_top))) * 100
# Out:
# 33.33333333333333
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#activated
# dc.plot_targets(results_df, stat='stat', source_name='GLIS3', net=collectri, top=15,save='../figures/WT/t1_GLIS3_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='FGF2', net=collectri, top=15,save='../figures/WT/t1_FGF2_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='MAFA', net=collectri, top=15,save='../figures/WT/t1_MAFA_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='NKX6-1', net=collectri, top=15,save='../figures/WT/t1_NKX6-1_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='VHL', net=collectri, top=15,save='../figures/WT/t1_VHL_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='HIVEP1', net=collectri, top=15,save='../figures/WT/t1_HIVEP1_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='PREB', net=collectri, top=15,save='../figures/WT/t1_PREB_targets.png')
# #inhibited
# dc.plot_targets(results_df, stat='stat', source_name='JUN', net=collectri, top=15,save='../figures/WT/t1_JUN_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='TFAP2A', net=collectri, top=15,save='../figures/WT/t1_TFAP2A_targets.png')

# %% [markdown]
# ## Plot Network

# %%
dc.plot_network(
    net=collectri,
    obs=mat,
    act=tf_acts,
    n_sources=['GLIS3', 'FGF2', 'MAFA', 'NKX6-1', 'VHL', 'HIVEP1', 'PREB', 'JUN', 'TFAP2A'],
    n_targets=10,
    node_size=0.5,
    label_size=8,
    figsize=(10, 10),
    c_pos_w='darkgreen',
    c_neg_w='darkred',
    vcenter=True,
    save = '../figures/WT/t1_plot_networks.png'
)

# %%
# Extract logFCs and pvals
logFCs = results_df[['log2FoldChange']].T.rename(index={'log2FoldChange': 'treatment.vs.control'})
pvals = results_df[['padj']].T.rename(index={'padj': 'treatment.vs.control'})

# Plot
dc.plot_volcano(logFCs, pvals, 'treatment.vs.control', name='MAFA', net=collectri, top=10, sign_thr=0.05, lFCs_thr=0.5)

# %% [markdown]
# ### Pathway activity inference

# %%
# Retrieve PROGENy model weights
progeny = dc.get_progeny(top=500)
progeny

# %% [markdown]
# ### Activity inference with multivariate Linear Model (MLM)

# %%
# Infer pathway activities with mlm
pathway_acts, pathway_pvals = dc.run_mlm(mat=mat, net=progeny, verbose=True)
pathway_acts

# %%
dc.plot_barplot(
    pathway_acts,
    'treatment.vs.control',
    top=25,
    vertical=True,
    vmin=-5,
    vmax=5,
    save='../figures/WT/t1_pathway_activities.png'
)

# %%
# # increase activity
# dc.plot_targets(results_df, stat='stat', source_name='Androgen', net=progeny, top=20,save='../figures/WT/t1_Androgen_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='p53', net=progeny, top=30,save='../figures/WT/t1_p53_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='PI3K', net=progeny, top=30,save='../figures/WT/t1_PI3K_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='MAPK', net=progeny, top=30,save='../figures/WT/t1_MAPK_targets.png')
# # decrease activity
# dc.plot_targets(results_df, stat='stat', source_name='JAK-STAT', net=progeny, top=30, save='../figures/WT/t1_JAK-STAT_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='EGFR', net=progeny, top=20, save='../figures/WT/t1_EGFR_targets.png')

# Approach to investigate p53 -> PPI -> mechanism? -> ask -> Table with list of targets for each one of the pathways with statistics

# %% [markdown]
# ### Funtional enrichment of Biological Terms

# %%
# # The Molecular Signatures Database (MSigDB) is a resource containing a collection of gene sets annotated to different biological processes.
# msigdb = dc.get_resource('MSigDB')
# msigdb

# %%
# msigdb['collection'].unique()

# %%
# # Filter by hallmark
# msigdb = msigdb[msigdb['collection']=='hallmark']

# # Remove duplicated entries
# msigdb = msigdb[~msigdb.duplicated(['geneset', 'genesymbol'])]

# # Rename
# msigdb.loc[:, 'geneset'] = [name.split('HALLMARK_')[1] for name in msigdb['geneset']]

# msigdb

# %% [markdown]
# ## ORA

# %%
# # Infer enrichment with ora using significant deg
# top_genes = results_df[results_df['padj'] < 0.05]

# # Run ora
# enr_pvals = dc.get_ora_df(
#     df=top_genes,
#     net=msigdb,
#     source='geneset',
#     target='genesymbol'
# )

# enr_pvals.head()

# %%
# dc.plot_dotplot(
#     enr_pvals.sort_values('Combined score', ascending=False).head(15),
#     x='Combined score',
#     y='Term',
#     s='Odds ratio',
#     c='FDR p-value',
#     scale=0.4,
#     figsize=(5, 10),
#     save='../figures/WT/t1_ORA.png'
# )
