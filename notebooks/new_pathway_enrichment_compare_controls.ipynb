# %% [markdown]
# # Pathway enrichment check controls
# Collab Theis - Hebrok labs
#
# Data analysis: Alexander Fastner
#
# based on Data analysis by: Sara Jimenez
#
# Data generation: Veronica Cochrane

# %% [markdown]
# ## Loading Packages

# %%
import scanpy as sc
import decoupler as dc
import anndata as ad
# Only needed for processing
import numpy as np
import pandas as pd
from anndata import AnnData

# %% [markdown]
# ## Load Data

# %%
# Read raw data and process it
wtdata = pd.read_csv('../data/MAFA_WT_gene_count.txt', index_col=20, sep='\t').T
wtdata
mutdata = pd.read_csv('../data/S64F_gene_count.txt', index_col=18, sep='\t').T
mutdata
# Out:
# gene_name       CHGA  MT-CO1     GCG     INS  MT-ND4  EEF1A1     TTR     SST  \
# MAFAS64F_001  611586  314216  328546  267945  135623  122556  169291  198632
# MAFAS64F_002  575049  409669  243106  184948  187221   88068  124960  108400
# MAFAS64F_003  824730  218574  321668  278746   92467  111493  152005  118341
# MAFAS64F_004  858370  262758  351032  358769  109622  134079  175299  232638
# MAFAS64F_005  828227  500390  312265  281623  228104  110909  158423  149446
# MAFAS64F_006  882622  241947  252381  210988  113488  104409  103355   75316
# MAFAS64F_007  698088  281983  336437  280200  118392  117157  164344  222087
# MAFAS64F_008  695656  403657  227741  176757  183399   79146   98225   93109
# MAFAS64F_009  656783  205008  214125  229070   97473  115874  111309   52115
# MAFAS64F_010  992861  158438  381157  341457   70606  135710  161331  154493
# MAFAS64F_011  956459  418530  402691  265441  183002  115507  144222   99429
# ...

# %%
# Transform to AnnData object
wtdata = AnnData(wtdata, dtype=np.float32)
wtdata.var_names_make_unique()
wtdata
mutdata = AnnData(mutdata, dtype=np.float32)
mutdata.var_names_make_unique()
mutdata
# Out:
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/anndata/_core/anndata.py:1900: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/anndata/_core/anndata.py:1900: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 18 × 58735

# %%
# Read metadata 
metadataWT = pd.read_csv('../data/2023_MAFA_MetaData.txt', index_col=0, sep='\t')
metadataWT
metadataMut = pd.read_csv('../data/2023_MAFA_MetaData_Mut.txt', index_col=0, sep='\t')
metadataMut
# Out:
#              Sample_Description Treatment Genotype TimePoint  Batch DOX  \
# SampleID
# MAFAS64F_001        ControlS64F   Control     S64F        T0      2   N
# MAFAS64F_002        ControlS64F   Control     S64F        T0      2   N
# MAFAS64F_003        ControlS64F   Control     S64F        T0      2   N
# MAFAS64F_004        ControlS64F   Control     S64F        T2      2   Y
# MAFAS64F_005        ControlS64F   Control     S64F        T2      2   Y
# MAFAS64F_006        ControlS64F   Control     S64F        T2      2   Y
# MAFAS64F_007        ControlS64F   Control     S64F        T1      2   Y
# MAFAS64F_008        ControlS64F   Control     S64F        T1      2   Y
# MAFAS64F_009        ControlS64F   Control     S64F        T1      2   Y
# MAFAS64F_010           MAFAS64F      MAFA     S64F        T0      2   N
# MAFAS64F_011           MAFAS64F      MAFA     S64F        T0      2   N
# MAFAS64F_012           MAFAS64F      MAFA     S64F        T0      2   N
# ...

# %%
wtdata.obs['condition'] = metadataWT['Treatment']
wtdata.obs['time_point'] = metadataWT['TimePoint']
wtdata.obs['DOX'] = metadataWT['DOX']
wtdata.obs
mutdata.obs['condition'] = metadataMut['Treatment']
mutdata.obs['time_point'] = metadataMut['TimePoint']
mutdata.obs['DOX'] = metadataMut['DOX']
mutdata.obs
# Out:
#              condition time_point DOX
# MAFAS64F_001   Control         T0   N
# MAFAS64F_002   Control         T0   N
# MAFAS64F_003   Control         T0   N
# MAFAS64F_004   Control         T2   Y
# MAFAS64F_005   Control         T2   Y
# MAFAS64F_006   Control         T2   Y
# MAFAS64F_007   Control         T1   Y
# MAFAS64F_008   Control         T1   Y
# MAFAS64F_009   Control         T1   Y
# MAFAS64F_010      MAFA         T0   N
# MAFAS64F_011      MAFA         T0   N
# MAFAS64F_012      MAFA         T0   N
# MAFAS64F_013      MAFA         T2   Y
# MAFAS64F_014      MAFA         T2   Y
# MAFAS64F_015      MAFA         T2   Y
# MAFAS64F_016      MAFA         T1   Y
# MAFAS64F_017      MAFA         T1   Y
# MAFAS64F_018      MAFA         T1   Y

# %%
# split data set by timepoint and control
subset_t0_WT = wtdata[wtdata.obs.time_point == 'T0']
subset_t0_WT = subset_t0_WT[subset_t0_WT.obs.condition == 'Control']
print("Subset for time point T0:")
print(subset_t0_WT)
subset_t0_WT.obs
subset_t0_Mut = mutdata[mutdata.obs.time_point == 'T0']
subset_t0_Mut = subset_t0_Mut[subset_t0_Mut.obs.condition == 'Control']
print("Subset for time point T0:")
print(subset_t0_Mut)
subset_t0_Mut.obs
# Out:
# Subset for time point T0:
# View of AnnData object with n_obs × n_vars = 3 × 58735
#     obs: 'condition', 'time_point', 'DOX'
# Subset for time point T0:
# View of AnnData object with n_obs × n_vars = 3 × 58735
#     obs: 'condition', 'time_point', 'DOX'
#              condition time_point DOX
# MAFAS64F_001   Control         T0   N
# MAFAS64F_002   Control         T0   N
# MAFAS64F_003   Control         T0   N

# %% [markdown]
# ## Quality Control

# %%
#check various filter points
dc.plot_filter_by_expr(subset_t0_WT, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1,save='../figures/Control/subset_t0_WT_QC.png')
dc.plot_filter_by_expr(subset_t0_Mut, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1,save='../figures/Control/subset_t0_Mut_QC.png')

# %%
# Obtain genes that pass the thresholds
genes_WT = dc.filter_by_expr(subset_t0_WT, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1)
genes_WT.size
genes_Mut = dc.filter_by_expr(subset_t0_Mut, group=None, min_count=10, min_total_count=15, large_n=1, min_prop=1)
genes_Mut.size
# Out:
# 16135

# %%
# Filter by these genes
wtdata = subset_t0_WT[:, genes_WT].copy()
wtdata
mutdata = subset_t0_Mut[:, genes_Mut].copy()
mutdata
#modify to add _wt/mut to condition to seperate
wtdata.obs['condition'] = wtdata.obs['condition'].astype(str) + "_wt"
mutdata.obs['condition'] = mutdata.obs['condition'].astype(str) + "_mut"
adata = ad.concat([wtdata, mutdata], axis=0)

# %%
adata.obs
# Out:
#                 condition time_point DOX
# MAFAWT_012     Control_wt         T0   N
# MAFAWT_013     Control_wt         T0   N
# MAFAWT_014     Control_wt         T0   N
# MAFAS64F_001  Control_mut         T0   N
# MAFAS64F_002  Control_mut         T0   N
# MAFAS64F_003  Control_mut         T0   N

# %%
#!pip install pydeseq2

# %%
# Import DESeq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
adata.X = np.round(adata.X,0)

# %%
# Build DESeq2 object
dds = DeseqDataSet(
    adata=adata,
    design_factors='condition',
    refit_cooks=True,
    n_cpus=8,
)
# Out:
# /root/anaconda3/envs/decoupler/lib/python3.9/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(

# %%
# Compute LFCs
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.01 seconds.
#
# Fitting dispersions...
# ... done in 22.00 seconds.
#
# Fitting dispersion trend curve...
# ... done in 3.98 seconds.
#
# Fitting MAP dispersions...
# ... done in 23.71 seconds.
#
# Fitting LFCs...
# ... done in 1.84 seconds.
#
# Refitting 0 outliers.

# %%
dds.obs.condition
# Out:
# MAFAWT_012       Control-wt
# MAFAWT_013       Control-wt
# MAFAWT_014       Control-wt
# MAFAS64F_001    Control-mut
# MAFAS64F_002    Control-mut
# MAFAS64F_003    Control-mut
# Name: condition, dtype: object

# %%
# Extract contrast 
stat_res = DeseqStats(dds, contrast=["condition", 'Control-mut', 'Control-wt'], n_cpus=8)

# %%
# Compute Wald test
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Control-mut vs Control-wt
# ... done in 0.96 seconds.
#                  baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# gene_name
# CHGA        671761.687500       -0.006030  0.113047 -0.053337  9.574636e-01
# MT-CO1      275293.031250        0.483189  0.342470  1.410894  1.582758e-01
# GCG         300148.906250       -0.013268  0.170944 -0.077618  9.381321e-01
# INS         185495.562500        0.942982  0.142911  6.598364  4.157186e-11
# MT-ND4      121109.414062        0.494207  0.383699  1.288007  1.977435e-01
# ...                   ...             ...       ...       ...           ...
# IMPDH1P5        18.930618        0.678786  0.478594  1.418291  1.561059e-01
# AC024132.3      21.692627        0.624674  0.482065  1.295829  1.950342e-01
# AC006111.2      12.625878       -0.055100  0.331092 -0.166419  8.678275e-01
# ...

# %%
# Shrink LFCs
stat_res.lfc_shrink(coeff='condition_Control-wt_vs_Control-mut')
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition Control-wt vs Control-mut
# ... done in 4.31 seconds.
#                  baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# gene_name
# CHGA        671761.687500        1.409417  0.136792 -0.053337  9.574636e-01
# MT-CO1      275293.031250        2.066698  0.471516  1.410894  1.582758e-01
# GCG         300148.906250        0.005578  0.145322 -0.077618  9.381321e-01
# INS         185495.562500       -0.814281  0.148106  6.598364  4.157186e-11
# MT-ND4      121109.414062        0.468049  0.600027  1.288007  1.977435e-01
# ...                   ...             ...       ...       ...           ...
# IMPDH1P5        18.930618       -0.097751  0.254295  1.418291  1.561059e-01
# AC024132.3      21.692627       -0.086574  0.246944  1.295829  1.950342e-01
# AC006111.2      12.625878       -0.144270  0.378133 -0.166419  8.678275e-01
# ...

# %%
# Extract results
results_df = stat_res.results_df
results_df
# Out:
#                  baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# gene_name
# CHGA        671761.687500        1.409417  0.136792 -0.053337  9.574636e-01
# MT-CO1      275293.031250        2.066698  0.471516  1.410894  1.582758e-01
# GCG         300148.906250        0.005578  0.145322 -0.077618  9.381321e-01
# INS         185495.562500       -0.814281  0.148106  6.598364  4.157186e-11
# MT-ND4      121109.414062        0.468049  0.600027  1.288007  1.977435e-01
# ...                   ...             ...       ...       ...           ...
# IMPDH1P5        18.930618       -0.097751  0.254295  1.418291  1.561059e-01
# AC024132.3      21.692627       -0.086574  0.246944  1.295829  1.950342e-01
# AC006111.2      12.625878       -0.144270  0.378133 -0.166419  8.678275e-01
# AL359183.1      14.403987       -0.008847  0.232929  0.158976  8.736879e-01
# AC106886.5      15.550400       -0.067347  0.240726  1.096491  2.728640e-01
#
#                     padj
# gene_name
# ...

# %%
#!pip install adjustText

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
dc.plot_volcano_df(
    results_df,
    x='log2FoldChange',
    y='padj',
    top=20,
    ax=ax
)
ax.set_xlim(-10, 10)
ax.set_ylim(0, 300)
plt.savefig('../figures/Control/t0_volcano.png')

# %%
mat = results_df[['stat']].T.rename(index={'stat': 'treatment.vs.control'})
mat
# Out:
# gene_name                 CHGA    MT-CO1       GCG       INS    MT-ND4  \
# treatment.vs.control -0.053337  1.410894 -0.077618  6.598364  1.288007
#
# gene_name               EEF1A1    MT-ND5       TTR    MT-CO2    MT-CYB  ...  \
# treatment.vs.control  2.249529  0.928304  4.819849  2.952712  0.976379  ...
#
# gene_name               ZNF135  AP005329.2    CASC19    NPIPB2  AC005828.4  \
# treatment.vs.control  2.360854    0.414898 -0.492159  0.482748   -1.552814
#
# gene_name             IMPDH1P5  AC024132.3  AC006111.2  AL359183.1  AC106886.5
# treatment.vs.control  1.418291    1.295829   -0.166419    0.158976    1.096491
#
# [1 rows x 15623 columns]

# %% [markdown]
# ### Transcription factor activity inference

# %%
#collectri = dc.get_collectri(organism='human')
collectri = pd.read_csv("./collectri.csv")
collectri
# Out:
#        source          target  weight  \
# 0         MYC            TERT       1
# 1        SPI1           BGLAP       1
# 2       SMAD3             JUN       1
# 3       SMAD4             JUN       1
# 4      STAT5A             IL2       1
# ...       ...             ...     ...
# 43173    NFKB  hsa-miR-143-3p       1
# 43174     AP1     hsa-miR-206       1
# 43175    NFKB   hsa-miR-21-5p       1
# 43176    NFKB  hsa-miR-224-5p       1
# 43177     AP1     hsa-miR-144       1
#
#                                                     PMID
# 0      10022128;10491298;10606235;10637317;10723141;1...
# 1                                               10022617
# 2                                      10022869;12374795
# 3                                      10022869;12374795
# 4      10022878;11435608;17182565;17911616;22854263;2...
# ...                                                  ...
# 43173                                           19472311
# ...

# %% [markdown]
# ### Activity inference with Univariate Linear Model (ULM)

# %%
# Infer TF activities with ulm
tf_acts, tf_pvals = dc.run_ulm(mat=mat, net=collectri, verbose=True)
tf_acts
# Out:
# Running ulm on mat with 1 samples and 15623 targets for 650 sources.
#                           ABL1       AHR      AHRR      AIP      AIRE  \
# treatment.vs.control -0.966472  0.241301  1.641572  0.31902  2.600014
#
#                            AP1     APEX1        AR    ARID1A    ARID3A  ...  \
# treatment.vs.control  0.595926  0.493479 -0.778309  0.401278 -0.063645  ...
#
#                        ZNF354C    ZNF362   ZNF382    ZNF384   ZNF395  \
# treatment.vs.control -1.604109  0.564654  0.56129  0.191737 -1.70113
#
#                         ZNF436    ZNF699     ZNF76   ZNF804A     ZNF91
# treatment.vs.control  0.867778  1.179815 -0.434643 -1.945948  0.608825
#
# [1 rows x 650 columns]

# %%
dc.plot_barplot(
    tf_acts,
    'treatment.vs.control',
    top=25,
    vertical=True,
    vmin=4,
    vmax=4,
    save='../figures/Control/t0_tf_activities.png'
)

# %%
# #activated
# dc.plot_targets(results_df, stat='stat', source_name='ETV2', net=collectri, top=15,save='../figures/Control/t0_ETV2_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='MYC', net=collectri, top=15,save='../figures/Control/t0_MYC_targets.png')
# #inhibited
# dc.plot_targets(results_df, stat='stat', source_name='FEV', net=collectri, top=15,save='../figures/Control/t0_FEV_targets.png')
# #MAFA
# dc.plot_targets(results_df, stat='stat', source_name='MAFA', net=collectri, top=15,save='../figures/Control/t0_MAFA_targets.png')

# %% [markdown]
# ## Plot Network

# %%
dc.plot_network(
    net=collectri,
    obs=mat,
    act=tf_acts,
    n_sources=['ETV2', 'MYC', 'FEV', 'MAFA'],
    n_targets=10,
    node_size=0.5,
    label_size=8,
    figsize=(10, 10),
    c_pos_w='darkgreen',
    c_neg_w='darkred',
    vcenter=True,
    save = '../figures/Control/t0_plot_networks.png'
)

# %%
# Extract logFCs and pvals
logFCs = results_df[['log2FoldChange']].T.rename(index={'log2FoldChange': 'treatment.vs.control'})
pvals = results_df[['padj']].T.rename(index={'padj': 'treatment.vs.control'})

# Plot
dc.plot_volcano(logFCs, pvals, 'treatment.vs.control', name='MAFA', net=collectri, top=10, sign_thr=0.05, lFCs_thr=0.5)

# %% [markdown]
# ### Pathway activity inference

# %%
# Retrieve PROGENy model weights
progeny = dc.get_progeny(top=500)
progeny
# Out:
#         source   target     weight       p_value
# 0     Androgen  TMPRSS2  11.490631  0.000000e+00
# 1     Androgen   NKX3-1  10.622551  2.242078e-44
# 2     Androgen   MBOAT2  10.472733  4.624285e-44
# 3     Androgen     KLK2  10.176186  1.944414e-40
# 4     Androgen     SARG  11.386852  2.790209e-40
# ...        ...      ...        ...           ...
# 6995       p53    ZMYM4  -2.325752  1.522388e-06
# 6996       p53    CFDP1  -1.628168  1.526045e-06
# 6997       p53   VPS37D   2.309503  1.537098e-06
# 6998       p53    TEDC1  -2.274823  1.547037e-06
# 6999       p53  CCDC138  -3.205113  1.568160e-06
#
# [7000 rows x 4 columns]

# %% [markdown]
# ### Activity inference with multivariate Linear Model (MLM)

# %%
# Infer pathway activities with mlm
pathway_acts, pathway_pvals = dc.run_mlm(mat=mat, net=progeny, verbose=True)
pathway_acts
# Out:
# Running mlm on mat with 1 samples and 15623 targets for 14 sources.
#                       Androgen      EGFR  Estrogen   Hypoxia  JAK-STAT  \
# treatment.vs.control -0.664186  2.716584  1.958431 -2.630918 -6.667063
#
#                          MAPK      NFkB      PI3K      TGFb      TNFa  \
# treatment.vs.control -0.48142 -0.719014 -4.013913  0.368506  0.422427
#
#                          Trail      VEGF       WNT       p53
# treatment.vs.control  0.480258  0.052304  1.876592 -0.166119

# %%
dc.plot_barplot(
    pathway_acts,
    'treatment.vs.control',
    top=25,
    vertical=True,
    vmin=-5,
    vmax=5,
    save='../figures/Control/t0_pathway_activities.png'
)

# %%
# # increase activity
# dc.plot_targets(results_df, stat='stat', source_name='EGFR', net=progeny, top=30,save='../figures/Control/t0_EGFR_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='Estrogen', net=progeny, top=30, save='../figures/Control/t0_Estrogen_targets.png')
# dc.plot_targets(results_df, stat='stat', source_name='WNT', net=progeny, top=30,save='../figures/Control/t0_WNT_targets.png')
# # decrease activity
# dc.plot_targets(results_df, stat='stat', source_name='JAK-STAT', net=progeny, top=30, save='../figures/Control/t0_JAK-STAT_targets.png')

# # Approach to investigate p53 -> PPI -> mechanism? -> ask -> Table with list of targets for each one of the pathways with statistics

# %% [markdown]
# ### Funtional enrichment of Biological Terms

# %%
# # The Molecular Signatures Database (MSigDB) is a resource containing a collection of gene sets annotated to different biological processes.
# msigdb = dc.get_resource('MSigDB')
# msigdb

# %%
# msigdb['collection'].unique()

# %%
# # Filter by hallmark
# msigdb = msigdb[msigdb['collection']=='hallmark']

# # Remove duplicated entries
# msigdb = msigdb[~msigdb.duplicated(['geneset', 'genesymbol'])]

# # Rename
# msigdb.loc[:, 'geneset'] = [name.split('HALLMARK_')[1] for name in msigdb['geneset']]

# msigdb

# %% [markdown]
# ## ORA

# %%
# # Infer enrichment with ora using significant deg
# top_genes = results_df[results_df['padj'] < 0.05]

# # Run ora
# enr_pvals = dc.get_ora_df(
#     df=top_genes,
#     net=msigdb,
#     source='geneset',
#     target='genesymbol'
# )

# enr_pvals.head()

# %%
# dc.plot_dotplot(
#     enr_pvals.sort_values('Combined score', ascending=False).head(15),
#     x='Combined score',
#     y='Term',
#     s='Odds ratio',
#     c='FDR p-value',
#     scale=0.4,
#     figsize=(5, 10),
#     save='../figures/Control/t0_ORA.png'
# )

# %% [markdown]
# # Annotation
